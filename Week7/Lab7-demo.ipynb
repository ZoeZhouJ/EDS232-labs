# %%
import seaborn as sns
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from scipy.stats import uniform, randint
import xgboost as xgb

# %%
# Generate a moon dataset
# Generate a toy dataset
X, y = make_moons(n_samples = 1000, noise = 0.2, random_state=808)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=808)

# Define XGBoost model
model = xgb.XGBClassifier(eval_metrics='logloss', random_state=808)

# Define hyperparameter distribution
param_dist = {
    "n_estimators": randint(50,300),
    "learning_rate": uniform(0.01, 0.3),
    "max_depth": randint(2,10),
    "subsample": uniform(0.5,0.5),
    "colsample_bytree": uniform(0.5,0.5)
}

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    model, param_dist, n_iter =20, scoring="accuracy",
    cv=3, verbose=1, random_state=808)

# Run random search
random_search.fit(X_train, y_train)

# Get search results as a DataFrame
results = pd.DataFrame(random_search.cv_results_)

# Extract hyperparameters and accuracy
params_to_plot = ["param_learning_rate", "param_n_sestimators", "param_max_depth", "param_subsample", 
                 "param_colsample_bytree"]

accuracy = results['mean_test_score']
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:13:40] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:17:28] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:21:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:25:06] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [18:37:07] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [19:31:59] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [19:42:37] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [19:54:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [19:59:22] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:03:27] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:07:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:13:01] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:17:59] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:22:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:34:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:39:52] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:41:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:43:00] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:44:35] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:52:38] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:58:52] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:04:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:09:39] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:14:42] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:19:16] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:20:35] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:21:53] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:23:05] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:25:28] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:27:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:31:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:34:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:37:21] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:39:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:41:38] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:43:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/anaconda3/envs/ml-env/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [21:44:49] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1713397725960/work/src/learner.cc:742:
# Parameters: { "eval_metrics" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
# Generate scatter plots for each hyperparameter vs. accuracy
for param in params_to_plot:
    sns.scatterplot(x=results[param], y=accuracy),
    plt.title(f'Effect of {param}) on Model Accuracy')
    plt.show()
